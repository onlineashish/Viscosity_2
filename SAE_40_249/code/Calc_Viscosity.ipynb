# %%
import cv2

# %%
for i in range(32,80):  ### start from 7th frame i.e. 7 + 25 = 32nd frame
    img_last =  f'/home/cvig13/Viscosity_2/SAE_40_249/data/video_with_bgremoved/maskedframes_first/frame{i}.jpg'
    img_first = f'/home/cvig13/Viscosity_2/SAE_40_249/data/video_with_bgremoved/maskedframes_first/frame{i-25}.jpg'
    img_last = cv2.imread(img_last)
    img_first = cv2.imread(img_first)

    # Convert the frame to grayscale
    gray_last = cv2.cvtColor(img_last, cv2.COLOR_BGR2GRAY)
    gray_first = cv2.cvtColor(img_first, cv2.COLOR_BGR2GRAY)

     # Threshold the frame to create a binary image
    _, binary_frame_last = cv2.threshold(gray_last, 200, 255, cv2.THRESH_BINARY)
    _, binary_frame_first = cv2.threshold(gray_first, 200, 255, cv2.THRESH_BINARY)

    # Find contours in the binary image
    contours_last, _ = cv2.findContours(binary_frame_last, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours_first, _ = cv2.findContours(binary_frame_first, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate over the contours and find the centroid of the white dot
    
    for c in contours_last:
        M = cv2.moments(c)
        if M["m00"] != 0:
            cX_last = int(M["m10"] / M["m00"])
            cY_last = int(M["m01"] / M["m00"])
            break
        
    for c in contours_first:
        M = cv2.moments(c)
        if M["m00"] != 0:
            cX_first = int(M["m10"] / M["m00"])
            cY_first = int(M["m01"] / M["m00"])
            break

    distance = ((cX_last - cX_first)**2 + (cY_last - cY_first)**2)**0.5

    print(f'frame{i}-{i-25} distance: {distance} pixels')
# Out:
# frame32-7 distance: 295.0271173977063 pixels
# frame33-8 distance: 295.01525384291574 pixels
# frame34-9 distance: 295.01525384291574 pixels
# frame35-10 distance: 295.01525384291574 pixels
# frame36-11 distance: 296.00675667964066 pixels
# frame37-12 distance: 296.0270257932542 pixels
# frame38-13 distance: 296.00675667964066 pixels
# frame39-14 distance: 297.0151511286924 pixels
# frame40-15 distance: 296.0152023123137 pixels
# frame41-16 distance: 297.00673393039426 pixels
# frame42-17 distance: 295.01525384291574 pixels
# frame43-18 distance: 296.0152023123137 pixels
# frame44-19 distance: 295.0016949103852 pixels
# frame45-20 distance: 296.00675667964066 pixels
# frame46-21 distance: 296.00675667964066 pixels
# frame47-22 distance: 295.0016949103852 pixels
# frame48-23 distance: 296.00675667964066 pixels
# frame49-24 distance: 294.00680264238787 pixels
# frame50-25 distance: 295.006779583114 pixels
# frame51-26 distance: 294.00680264238787 pixels
# frame52-27 distance: 293.0068258590574 pixels
# frame53-28 distance: 294.0017006753532 pixels
# frame54-29 distance: 293.00170647967224 pixels
# frame55-30 distance: 293.00170647967224 pixels
# frame56-31 distance: 292.00171232374646 pixels
# frame57-32 distance: 292.0068492347397 pixels
# frame58-33 distance: 292.0068492347397 pixels
# frame59-34 distance: 291.00171820798585 pixels
# frame60-35 distance: 291.00171820798585 pixels
# frame61-36 distance: 290.0017241328058 pixels
# frame62-37 distance: 290.0017241328058 pixels
# frame63-38 distance: 289.0017300986276 pixels
# frame64-39 distance: 288.0 pixels
# frame65-40 distance: 287.0 pixels
# frame66-41 distance: 287.0017421549911 pixels
# frame67-42 distance: 287.0017421549911 pixels
# frame68-43 distance: 287.0 pixels
# frame69-44 distance: 285.0070174574654 pixels
# frame70-45 distance: 288.00173610587836 pixels
# frame71-46 distance: 276.0018115882575 pixels
# frame72-47 distance: 284.0017605579233 pixels
# frame73-48 distance: 283.0017667789373 pixels
# frame74-49 distance: 283.0017667789373 pixels
# frame75-50 distance: 280.0017857085915 pixels
# frame76-51 distance: 279.00716836669267 pixels
# frame77-52 distance: 281.0 pixels
# frame78-53 distance: 280.0017857085915 pixels
# frame79-54 distance: 283.0070670495703 pixels

# %%
for i in range(32,82):
    img_last =  f'/home/cvig13/Viscosity_2/SAE_40_249/data/video_with_bgremoved/maskedframes_second/frame{i}.jpg'
    img_first = f'/home/cvig13/Viscosity_2/SAE_40_249/data/video_with_bgremoved/maskedframes_second/frame{i-25}.jpg'
    img_last = cv2.imread(img_last)
    img_first = cv2.imread(img_first)

    # Convert the frame to grayscale
    gray_last = cv2.cvtColor(img_last, cv2.COLOR_BGR2GRAY)
    gray_first = cv2.cvtColor(img_first, cv2.COLOR_BGR2GRAY)

     # Threshold the frame to create a binary image
    _, binary_frame_last = cv2.threshold(gray_last, 200, 255, cv2.THRESH_BINARY)
    _, binary_frame_first = cv2.threshold(gray_first, 200, 255, cv2.THRESH_BINARY)

    # Find contours in the binary image
    contours_last, _ = cv2.findContours(binary_frame_last, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours_first, _ = cv2.findContours(binary_frame_first, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate over the contours and find the centroid of the white dot
    
    for c in contours_last:
        M = cv2.moments(c)
        if M["m00"] != 0:
            cX_last = int(M["m10"] / M["m00"])
            cY_last = int(M["m01"] / M["m00"])
            break
        
    for c in contours_first:
        M = cv2.moments(c)
        if M["m00"] != 0:
            cX_first = int(M["m10"] / M["m00"])
            cY_first = int(M["m01"] / M["m00"])
            break

    distance = ((cX_last - cX_first)**2 + (cY_last - cY_first)**2)**0.5

    print(f'frame{i}-{i-25} distance: {distance} pixels')
# Out:
# frame32-7 distance: 295.0271173977063 pixels
# frame33-8 distance: 295.0271173977063 pixels
# frame34-9 distance: 294.0153057240388 pixels
# frame35-10 distance: 295.01525384291574 pixels
# frame36-11 distance: 296.0152023123137 pixels
# frame37-12 distance: 297.0269348055829 pixels
# frame38-13 distance: 297.0151511286924 pixels
# frame39-14 distance: 295.0271173977063 pixels
# frame40-15 distance: 295.01525384291574 pixels
# frame41-16 distance: 296.0270257932542 pixels
# frame42-17 distance: 295.0271173977063 pixels
# frame43-18 distance: 297.0151511286924 pixels
# frame44-19 distance: 296.0152023123137 pixels
# frame45-20 distance: 297.0151511286924 pixels
# frame46-21 distance: 295.01525384291574 pixels
# frame47-22 distance: 296.0152023123137 pixels
# frame48-23 distance: 296.0270257932542 pixels
# frame49-24 distance: 297.0151511286924 pixels
# frame50-25 distance: 295.006779583114 pixels
# frame51-26 distance: 296.0152023123137 pixels
# frame52-27 distance: 296.00675667964066 pixels
# frame53-28 distance: 297.00673393039426 pixels
# frame54-29 distance: 296.00675667964066 pixels
# frame55-30 distance: 295.01525384291574 pixels
# frame56-31 distance: 295.006779583114 pixels
# frame57-32 distance: 295.006779583114 pixels
# frame58-33 distance: 294.00680264238787 pixels
# frame59-34 distance: 295.006779583114 pixels
# frame60-35 distance: 294.00680264238787 pixels
# frame61-36 distance: 292.0068492347397 pixels
# frame62-37 distance: 294.00680264238787 pixels
# frame63-38 distance: 291.0068727710739 pixels
# frame64-39 distance: 293.00170647967224 pixels
# frame65-40 distance: 292.0068492347397 pixels
# frame66-41 distance: 292.0068492347397 pixels
# frame67-42 distance: 292.00171232374646 pixels
# frame68-43 distance: 291.0068727710739 pixels
# frame69-44 distance: 291.0068727710739 pixels
# frame70-45 distance: 289.0017300986276 pixels
# frame71-46 distance: 290.0068964697219 pixels
# frame72-47 distance: 289.0069203323685 pixels
# frame73-48 distance: 289.0 pixels
# frame74-49 distance: 287.0069685565143 pixels
# frame75-50 distance: 288.01562457616774 pixels
# frame76-51 distance: 287.0017421549911 pixels
# frame77-52 distance: 285.00175438056516 pixels
# frame78-53 distance: 282.00177304407146 pixels
# frame79-54 distance: 285.02806879323305 pixels
# frame80-55 distance: 284.0017605579233 pixels
# frame81-56 distance: 284.0017605579233 pixels

# %%
for i in range(32,80):
    img_last =  f'/home/cvig13/Viscosity_2/SAE_40_249/data/video_with_bgremoved/maskedframes_third/frame{i}.jpg'
    img_first = f'/home/cvig13/Viscosity_2/SAE_40_249/data/video_with_bgremoved/maskedframes_third/frame{i-25}.jpg'
    img_last = cv2.imread(img_last)
    img_first = cv2.imread(img_first)

    # Convert the frame to grayscale
    gray_last = cv2.cvtColor(img_last, cv2.COLOR_BGR2GRAY)
    gray_first = cv2.cvtColor(img_first, cv2.COLOR_BGR2GRAY)

     # Threshold the frame to create a binary image
    _, binary_frame_last = cv2.threshold(gray_last, 200, 255, cv2.THRESH_BINARY)
    _, binary_frame_first = cv2.threshold(gray_first, 200, 255, cv2.THRESH_BINARY)

    # Find contours in the binary image
    contours_last, _ = cv2.findContours(binary_frame_last, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours_first, _ = cv2.findContours(binary_frame_first, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Iterate over the contours and find the centroid of the white dot
    
    for c in contours_last:
        M = cv2.moments(c)
        if M["m00"] != 0:
            cX_last = int(M["m10"] / M["m00"])
            cY_last = int(M["m01"] / M["m00"])
            break
        
    for c in contours_first:
        M = cv2.moments(c)
        if M["m00"] != 0:
            cX_first = int(M["m10"] / M["m00"])
            cY_first = int(M["m01"] / M["m00"])
            break

    distance = ((cX_last - cX_first)**2 + (cY_last - cY_first)**2)**0.5

    print(f'frame{i}-{i-25} distance: {distance} pixels')
# Out:
# frame32-7 distance: 296.00675667964066 pixels
# frame33-8 distance: 296.00675667964066 pixels
# frame34-9 distance: 296.00675667964066 pixels
# frame35-10 distance: 296.00168918436935 pixels
# frame36-11 distance: 297.00673393039426 pixels
# frame37-12 distance: 297.00673393039426 pixels
# frame38-13 distance: 297.00673393039426 pixels
# frame39-14 distance: 297.00168349691216 pixels
# frame40-15 distance: 297.00168349691216 pixels
# frame41-16 distance: 297.00168349691216 pixels
# frame42-17 distance: 297.00168349691216 pixels
# frame43-18 distance: 296.00168918436935 pixels
# frame44-19 distance: 296.00168918436935 pixels
# frame45-20 distance: 292.0068492347397 pixels
# frame46-21 distance: 296.00168918436935 pixels
# frame47-22 distance: 295.0016949103852 pixels
# frame48-23 distance: 296.00168918436935 pixels
# frame49-24 distance: 295.0016949103852 pixels
# frame50-25 distance: 295.0 pixels
# frame51-26 distance: 295.0016949103852 pixels
# frame52-27 distance: 295.0016949103852 pixels
# frame53-28 distance: 294.0017006753532 pixels
# frame54-29 distance: 295.0016949103852 pixels
# frame55-30 distance: 294.0 pixels
# frame56-31 distance: 294.0 pixels
# frame57-32 distance: 293.0 pixels
# frame58-33 distance: 293.0 pixels
# frame59-34 distance: 292.0 pixels
# frame60-35 distance: 293.00170647967224 pixels
# frame61-36 distance: 292.0 pixels
# frame62-37 distance: 291.0 pixels
# frame63-38 distance: 290.0 pixels
# frame64-39 distance: 290.0 pixels
# frame65-40 distance: 290.0 pixels
# frame66-41 distance: 289.0 pixels
# frame67-42 distance: 288.0 pixels
# frame68-43 distance: 289.0017300986276 pixels
# frame69-44 distance: 288.0 pixels
# frame70-45 distance: 292.0154105522515 pixels
# frame71-46 distance: 286.0 pixels
# frame72-47 distance: 283.0017667789373 pixels
# frame73-48 distance: 288.0277764383151 pixels
# frame74-49 distance: 285.0 pixels
# frame75-50 distance: 285.0 pixels
# frame76-51 distance: 283.0017667789373 pixels
# frame77-52 distance: 281.00177935379696 pixels
# frame78-53 distance: 282.00177304407146 pixels
# frame79-54 distance: 281.0 pixels

# %%
#manual external diameter of SAE-40 tube : 58.50 mm
#corrosponding diameter in pixels : 212 pixels
# 212 pixels = 58.50 mm => 1 pixel = 0.275 mm
#  405 pixels = 111.75 mm => 0.11175 m
# 286 pixels =  78.75 mm => 0.07875 m
# 290 pixels =  79.75 mm => 0.07975 m

velocity = 0.07975 #m/s
g = 9.8
D_p = 2.49/1000# particle diameter in m
rho_p = 7800 # particle density in kg/m^3
rho_f = 860 # fluid density in kg/m^3
mu_f = g * (rho_p - rho_f) * D_p**2 / 18 / velocity # fluid viscosity in Pa.s
print(f"mu_f = {mu_f:.3f} Pa.s")
# Out:
# mu_f = 0.294 Pa.s
